# %%
import pandas as pd

# %%
df=pd.read_csv("sales_data_sample.csv",encoding="latin1")

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df2=df.copy()#generate copy of dataset
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df2.head() # Displaying First 5 rows
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
df2.head(10) # displaying first 10 rows
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
# 5        10168               36      96.66                1  3479.76
# 6        10180               29      86.13                9  2497.77
# 7        10188               48     100.00                1  5512.32
# 8        10201               22      98.57                2  2168.54
# 9        10211               41     100.00               14  4708.44
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# ...

# %%
df2.tail() # displaying last 5 rows
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#            ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 2818  12/2/2004 0:00   Shipped       4        12     2004  ...
# 2819  1/31/2005 0:00   Shipped       1         1     2005  ...
# 2820   3/1/2005 0:00  Resolved       1         3     2005  ...
# 2821  3/28/2005 0:00   Shipped       1         3     2005  ...
# 2822   5/6/2005 0:00   On Hold       2         5     2005  ...
#
#                ADDRESSLINE1  ADDRESSLINE2      CITY STATE POSTALCODE  COUNTRY  \
# ...

# %%
df2.tail(10) # displaying last 10 rows
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2813        10293               32      60.06                1  1921.92
# 2814        10306               35      59.51                6  2082.85
# 2815        10315               40      55.69                5  2227.60
# 2816        10327               37      86.74                4  3209.38
# 2817        10337               42      97.16                5  4080.72
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 2813    9/9/2004 0:00   Shipped       3         9     2004  ...
# ...

# %%
df2.info() # gives related information for the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %%
df2.describe() # gives statistical information for the dataset
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2823.000000      2823.000000  2823.000000      2823.000000
# mean   10258.725115        35.092809    83.658544         6.466171
# std       92.085478         9.741443    20.174277         4.225841
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10180.000000        27.000000    68.860000         3.000000
# 50%    10262.000000        35.000000    95.700000         6.000000
# 75%    10333.500000        43.000000   100.000000         9.000000
# max    10425.000000        97.000000   100.000000        18.000000
#
#               SALES       QTR_ID     MONTH_ID     YEAR_ID         MSRP
# count   2823.000000  2823.000000  2823.000000  2823.00000  2823.000000
# mean    3553.889072     2.717676     7.092455  2003.81509   100.715551
# std     1841.865106     1.203878     3.656633     0.69967    40.187912
# min      482.130000     1.000000     1.000000  2003.00000    33.000000
# ...

# %%
df2.columns # Check Column names
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %%
df2["SALES"] # SELECTING SINGLE COLUMN
# Out:
# 0       2871.00
# 1       2765.90
# 2       3884.34
# 3       3746.70
# 4       5205.27
#          ...
# 2818    2244.40
# 2819    3978.51
# 2820    5417.57
# 2821    2116.16
# 2822    3079.44
# Name: SALES, Length: 2823, dtype: float64

# %%
df2[["ORDERNUMBER","QUANTITYORDERED","PRICEEACH","SALES"]] # Selecting Multiple Columns
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH    SALES
# 0           10107               30      95.70  2871.00
# 1           10121               34      81.35  2765.90
# 2           10134               41      94.74  3884.34
# 3           10145               45      83.26  3746.70
# 4           10159               49     100.00  5205.27
# ...           ...              ...        ...      ...
# 2818        10350               20     100.00  2244.40
# 2819        10373               29     100.00  3978.51
# 2820        10386               43     100.00  5417.57
# 2821        10397               34      62.24  2116.16
# 2822        10414               47      65.52  3079.44
#
# [2823 rows x 4 columns]

# %%
df2.iloc[2]# index based location
# Out:
# ORDERNUMBER                                 10134
# QUANTITYORDERED                                41
# PRICEEACH                                   94.74
# ORDERLINENUMBER                                 2
# SALES                                     3884.34
# ORDERDATE                           7/1/2003 0:00
# STATUS                                    Shipped
# QTR_ID                                          3
# MONTH_ID                                        7
# YEAR_ID                                      2003
# PRODUCTLINE                           Motorcycles
# MSRP                                           95
# PRODUCTCODE                              S10_1678
# CUSTOMERNAME                      Lyon Souveniers
# PHONE                            +33 1 46 62 7555
# ADDRESSLINE1        27 rue du Colonel Pierre Avia
# ADDRESSLINE2                                  NaN
# CITY                                        Paris
# STATE                                         NaN
# ...

# %%
df2.loc[df2["SALES"]>11000]#filtering based on single condition
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 44          10312               48      100.0                3  11623.7
# 53          10424               50      100.0                6  12001.0
# 104         10403               66      100.0                9  11886.6
# 188         10127               46      100.0                2  11279.2
# 598         10407               76      100.0                2  14082.8
# 744         10322               50      100.0                6  12536.5
# 1062        10412               60      100.0                9  11887.8
# 1133        10333               46      100.0                2  11336.7
# 1995        10405               76      100.0                3  11739.7
#
#             ORDERDATE      STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 44    10/21/2004 0:00     Shipped       4        10     2004  ...
# 53     5/31/2005 0:00  In Process       2         5     2005  ...
# ...

# %%
df2[(df2["QUANTITYORDERED"]>60) & (df2["SALES"]>3000)] # filter based on Multiple conditions using AND
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER     SALES  \
# 25          10417               66     100.00                2   7516.08
# 104         10403               66     100.00                9  11886.60
# 131         10400               64     100.00                9   9661.44
# 264         10403               66     100.00                6   8648.64
# 418         10405               97      93.28                5   9048.16
# 473         10406               61     100.00                3   8374.69
# 598         10407               76     100.00                2  14082.80
# 624         10405               61      73.92                4   4509.12
# 1188        10406               65     100.00                1  10468.90
# 1288        10420               66      92.95                6   6134.70
# 1413        10407               66      66.99                4   4421.34
# 1666        10412               70     100.00               10   8498.00
# ...

# %%
df2[(df2["SALES"]> 14000)|(df2["YEAR_ID"]==2003)] # Filtering rows based on multiple conditions using OR
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2801        10153               50      60.06                4  3003.00
# 2802        10167               38      48.59               15  1846.42
# 2803        10177               40      50.23                6  2009.20
# 2804        10185               28      64.43                6  1804.04
# 2805        10197               42      50.23               12  2109.66
#
#             ORDERDATE     STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
# creating a new column using Assignment method
# df["CALCULATED_PRICE"]=df["QUANTITYORDERED"]*df["PRICEEACH"]
# df[[
#     "QUANTITYORDERED",
#     "PRICEEACH",
#     "CALCULATED_PRICE"
# ]]
df2.insert(3,"CALCULATED_PRICE",df2["QUANTITYORDERED"]*df2["PRICEEACH"])# iserting a column at specific position using loc and insert function

# %%
df2
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  CALCULATED_PRICE  \
# 0           10107               30      95.70           2871.00
# 1           10121               34      81.35           2765.90
# 2           10134               41      94.74           3884.34
# 3           10145               45      83.26           3746.70
# 4           10159               49     100.00           4900.00
# ...           ...              ...        ...               ...
# 2818        10350               20     100.00           2000.00
# 2819        10373               29     100.00           2900.00
# 2820        10386               43     100.00           4300.00
# 2821        10397               34      62.24           2116.16
# 2822        10414               47      65.52           3079.44
#
#       ORDERLINENUMBER    SALES        ORDERDATE    STATUS  QTR_ID  MONTH_ID  \
# 0                   2  2871.00   2/24/2003 0:00   Shipped       1         2
# ...

# %%
# df.drop("COLUMN_NAME",axis=1,inpace=True)# delete a specific column

# %%
#using .loc[] access some specific cell(rows & column) and then perform modifications on specific location
df2.loc[0,"SALES"]=2870
df2
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  CALCULATED_PRICE  \
# 0           10107               30      95.70           2871.00
# 1           10121               34      81.35           2765.90
# 2           10134               41      94.74           3884.34
# 3           10145               45      83.26           3746.70
# 4           10159               49     100.00           4900.00
# ...           ...              ...        ...               ...
# 2818        10350               20     100.00           2000.00
# 2819        10373               29     100.00           2900.00
# 2820        10386               43     100.00           4300.00
# 2821        10397               34      62.24           2116.16
# 2822        10414               47      65.52           3079.44
#
#       ORDERLINENUMBER    SALES        ORDERDATE    STATUS  QTR_ID  MONTH_ID  \
# 0                   2  2870.00   2/24/2003 0:00   Shipped       1         2
# ...

# %%
#increasing Sales by 5%(updating full column)
df2["SALES"]=df2["SALES"] *1.05
df2
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  CALCULATED_PRICE  \
# 0           10107               30      95.70           2871.00
# 1           10121               34      81.35           2765.90
# 2           10134               41      94.74           3884.34
# 3           10145               45      83.26           3746.70
# 4           10159               49     100.00           4900.00
# ...           ...              ...        ...               ...
# 2818        10350               20     100.00           2000.00
# 2819        10373               29     100.00           2900.00
# 2820        10386               43     100.00           4300.00
# 2821        10397               34      62.24           2116.16
# 2822        10414               47      65.52           3079.44
#
#       ORDERLINENUMBER      SALES        ORDERDATE    STATUS  QTR_ID  MONTH_ID  \
# 0                   2  3013.5000   2/24/2003 0:00   Shipped       1         2
# ...

# %%
df2["TERRITORY"]
# Out:
# 0        NaN
# 1       EMEA
# 2       EMEA
# 3        NaN
# 4        NaN
#         ...
# 2818    EMEA
# 2819    EMEA
# 2820    EMEA
# 2821    EMEA
# 2822     NaN
# Name: TERRITORY, Length: 2823, dtype: object

# %%
df2.drop(columns=["TERRITORY"],inplace=True)
df2
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  CALCULATED_PRICE  \
# 0           10107               30      95.70           2871.00
# 1           10121               34      81.35           2765.90
# 2           10134               41      94.74           3884.34
# 3           10145               45      83.26           3746.70
# 4           10159               49     100.00           4900.00
# ...           ...              ...        ...               ...
# 2818        10350               20     100.00           2000.00
# 2819        10373               29     100.00           2900.00
# 2820        10386               43     100.00           4300.00
# 2821        10397               34      62.24           2116.16
# 2822        10414               47      65.52           3079.44
#
#       ORDERLINENUMBER      SALES        ORDERDATE    STATUS  QTR_ID  MONTH_ID  \
# 0                   2  3013.5000   2/24/2003 0:00   Shipped       1         2
# ...

# %%
#Detect missing values 
#using isnull() func
df2.isnull()
#using isnull.sum() tells all the count of all missing values
df2.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# CALCULATED_PRICE       0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
#Handle Missing values
#1.removing missing data
#dropna()#-- removing missing values of any rows or columns
# df2.dropna(inplace=True)
#axis=0--> remove rows missing value s and axis=1---> remove columns missing values

# %%
# # filling missing values using fillna(value,inplace=True)
df2["POSTALCODE"]=df2["POSTALCODE"].fillna("Unknown")
df2["STATE"] = df2["STATE"].fillna("Unknown")
# Out:
# ORDERNUMBER                  int64
# QUANTITYORDERED              int64
# PRICEEACH                  float64
# CALCULATED_PRICE           float64
# ORDERLINENUMBER              int64
# SALES                      float64
# ORDERDATE           datetime64[ns]
# STATUS                      object
# QTR_ID                       int64
# MONTH                        int64
# YEAR                         int64
# PRODUCTLINE                 object
# MSRP                         int64
# PRODUCTCODE                 object
# CUSTOMERNAME                object
# PHONE                       object
# ADDRESSLINE1                object
# CITY                        object
# STATE                       object
# POSTALCODE                  object
# COUNTRY                     object
# CONTACTLASTNAME             object
# CONTACTFIRSTNAME            object
# DEALSIZE                    object
# dtype: object

# %%
df2.isnull().sum().sum()
# Out:
# np.int64(4083)

# %%
df2.drop(columns=["ADDRESSLINE2"],inplace=True)#dropping unaacessory Columns

# %%
df2
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  CALCULATED_PRICE  \
# 0           10107               30      95.70           2871.00
# 1           10121               34      81.35           2765.90
# 2           10134               41      94.74           3884.34
# 3           10145               45      83.26           3746.70
# 4           10159               49     100.00           4900.00
# ...           ...              ...        ...               ...
# 2818        10350               20     100.00           2000.00
# 2819        10373               29     100.00           2900.00
# 2820        10386               43     100.00           4300.00
# 2821        10397               34      62.24           2116.16
# 2822        10414               47      65.52           3079.44
#
#       ORDERLINENUMBER      SALES        ORDERDATE    STATUS  QTR_ID  MONTH_ID  \
# 0                   2  3013.5000   2/24/2003 0:00   Shipped       1         2
# ...

# %%
#Remove Acciodental Spaces
df2.columns = df2.columns.str.strip()
df2.columns.to_list()
# Out:
# ['ORDERNUMBER',
#  'QUANTITYORDERED',
#  'PRICEEACH',
#  'CALCULATED_PRICE',
#  'ORDERLINENUMBER',
#  'SALES',
#  'ORDERDATE',
#  'STATUS',
#  'QTR_ID',
#  'MONTH_ID',
#  'YEAR_ID',
#  'PRODUCTLINE',
#  'MSRP',
#  'PRODUCTCODE',
#  'CUSTOMERNAME',
#  'PHONE',
#  'ADDRESSLINE1',
#  'CITY',
#  'STATE',
#  'POSTALCODE',
#  'COUNTRY',
#  'CONTACTLASTNAME',
#  'CONTACTFIRSTNAME',
#  'DEALSIZE']

# %%
#Checking Text Columns 
df2["PRODUCTLINE"].nunique()
# Out:
# 7

# %%
#interpollution-->filling estimated values in missing values
#interpolate()

# %%
#Check for invalid numerical Values
df2["QUANTITYORDERED"] <= 0
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2818    False
# 2819    False
# 2820    False
# 2821    False
# 2822    False
# Name: QUANTITYORDERED, Length: 2823, dtype: bool

# %%
#Check categorical Consistency
# df2["PRODUCTLINE"].value_counts()
df2[["QUANTITYORDERED","PRODUCTLINE","SALES"]][df2["PRODUCTLINE"].isin(["Classic Cars","Motorcycles"])]
# df2["PRODUCTLINE"]
# Out:
#       QUANTITYORDERED   PRODUCTLINE      SALES
# 0                  30   Motorcycles  3013.5000
# 1                  34   Motorcycles  2904.1950
# 2                  41   Motorcycles  4078.5570
# 3                  45   Motorcycles  3934.0350
# 4                  49   Motorcycles  5465.5335
# ...               ...           ...        ...
# 2636               27  Classic Cars  3949.4385
# 2637               34  Classic Cars  4516.4070
# 2638               34  Classic Cars  1957.7880
# 2639               34  Classic Cars  3755.6400
# 2640               46  Classic Cars  3908.4360
#
# [1298 rows x 3 columns]

# %%
# df2["PRODUCTLINE"]

# %%
#sorting the data-->arrange the rows in a dataframe based on values of one or more column
# #sorting data in one column using sort_values()
df2.sort_values(by="ORDERLINENUMBER",ascending=True,inplace=True)
#Sort by multiple columns:
df2.sort_values(by=["SALES","QUANTITYORDERED"],ascending=[True,True],inplace=True)
df2
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  CALCULATED_PRICE  \
# 2249        10425               11      43.83            482.13
# 1287        10407                6      90.19            541.14
# 2044        10408               15      36.93            553.95
# 1551        10280               20      28.88            577.60
# 1818        10419               15      42.67            640.05
# ...           ...              ...        ...               ...
# 104         10403               66     100.00           6600.00
# 1062        10412               60     100.00           6000.00
# 53          10424               50     100.00           5000.00
# 744         10322               50     100.00           5000.00
# 598         10407               76     100.00           7600.00
#
#       ORDERLINENUMBER       SALES       ORDERDATE      STATUS  QTR_ID  \
# 2249                6    506.2365  5/31/2005 0:00  In Process       2
# ...

# %%
# #Aggregation----> summary statistics,mean and average calculation 
# summary statistics provide numerical value of columns 
# df2["Column_Name"].mean(),.sum(),min(),.max()
print("Sum of  sales Column:",df2["SALES"].sum())
print("Minimum Value of Sales Column:",df2["SALES"].min())
print("Maximun Value pf Sales Column:",df2["SALES"].max())
print("Mean of the sales column:",df2["SALES"].mean())
print("Std of the Sales column:",df2["SALES"].std())
# Out:
# Sum of  sales Column: 10534259.2425
# Minimum Value of Sales Column: 506.23650000000004
# Maximun Value pf Sales Column: 14786.94
# Mean of the sales column: 3731.5831535600423
# Std of the Sales column: 1933.9584990790856

# %%
#Grouping in pandas
#Group by method for basic grouping
df2.groupby ("QUANTITYORDERED",as_index=False)["PRICEEACH"].sum()
# Out:
#     QUANTITYORDERED  PRICEEACH
# 0                 6     190.19
# 1                10     188.14
# 2                11     143.83
# 3                12     100.00
# 4                13      81.33
# 5                15     221.93
# 6                16      75.48
# 7                18     244.76
# 8                19     197.92
# 9                20    7581.25
# 10               21    8517.88
# 11               22    8282.43
# 12               23    6262.98
# 13               24    7576.94
# 14               25    8001.34
# 15               26    8091.74
# 16               27    8539.77
# 17               28    6846.92
# 18               29    7899.15
# 19               30    6126.89
# 20               31    7731.13
# 21               32    7629.82
# 22               33    7593.12
# 23               34    9352.89
# 24               35    5722.45
# 25               36    7411.38
# 26               37    7286.14
# 27               38    7772.29
# 28               39    6613.28
# ...

# %%
#Merging and joining in dataframe--->comining two or more dataframes based on their column key column
#syntax--->pd.merge(df1,df2,on="COlUMN_NAME",how="type of join")
#inner,outer,left,right

# %%
#concatenation-->combine dataframes either vertically(row_wise) or horizontally(column wise)
#syntax_-->pd.concatenate([df1,df2],axis=0,ignore_index=True)

# %%
#Find Duplicate Rows
df2.duplicated()
#count duplicated Rows
df2.duplicated().sum()
#Remove duplicated rows
# df.drop_duplicates()
# #for Permananent
# df.drop_duplicates(inplace=True)
# Out:
# np.int64(0)

# %%
#Check Datatype
df2.dtypes
# Out:
# ORDERNUMBER           int64
# QUANTITYORDERED       int64
# PRICEEACH           float64
# CALCULATED_PRICE    float64
# ORDERLINENUMBER       int64
# SALES               float64
# ORDERDATE            object
# STATUS               object
# QTR_ID                int64
# MONTH_ID              int64
# YEAR_ID               int64
# PRODUCTLINE          object
# MSRP                  int64
# PRODUCTCODE          object
# CUSTOMERNAME         object
# PHONE                object
# ADDRESSLINE1         object
# CITY                 object
# STATE                object
# POSTALCODE           object
# COUNTRY              object
# CONTACTLASTNAME      object
# CONTACTFIRSTNAME     object
# DEALSIZE             object
# dtype: object

# %%
#convert datatypes
# df2["PHONE"]=df2["PHONE"].astype(int)

# %%
#USE NUMERIC WHEN DATA CONTAINS INVALID VALUES
# df2["PHONE"] = pd.to_numeric(
#     df2["PHONE"],
#     errors="coerce"
# )
# df2.dtypes

# %%
df2.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# CALCULATED_PRICE       0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
#apply()--->this allows you to apply a function to values
df2["SALES"]=df2["SALES"].apply(lambda x:x*1.10)#increase sales by 10%
df2
#another example
df2["CUSTOMERNAME"]=df2["CUSTOMERNAME"].apply(str.upper)
df2
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  CALCULATED_PRICE  \
# 2249        10425               11      43.83            482.13
# 1287        10407                6      90.19            541.14
# 2044        10408               15      36.93            553.95
# 1551        10280               20      28.88            577.60
# 1818        10419               15      42.67            640.05
# ...           ...              ...        ...               ...
# 104         10403               66     100.00           6600.00
# 1062        10412               60     100.00           6000.00
# 53          10424               50     100.00           5000.00
# 744         10322               50     100.00           5000.00
# 598         10407               76     100.00           7600.00
#
#       ORDERLINENUMBER        SALES       ORDERDATE      STATUS  QTR_ID  \
# 2249                6    556.86015  5/31/2005 0:00  In Process       2
# ...

# %%
#map() function---> used for mapping/replacing values

# %%
#Date & Time Function
df2["ORDERDATE"]=pd.to_datetime(df2["ORDERDATE"])
df2
#Extract Year
# df2["YEAR"]=df2["ORDERDATE"].dt.year
# df2
# #EXTRACT MONTH
# df2["MONTH"]=df2["ORDERDATE"].dt.month
# df2
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  CALCULATED_PRICE  \
# 2249        10425               11      43.83            482.13
# 1287        10407                6      90.19            541.14
# 2044        10408               15      36.93            553.95
# 1551        10280               20      28.88            577.60
# 1818        10419               15      42.67            640.05
# ...           ...              ...        ...               ...
# 104         10403               66     100.00           6600.00
# 1062        10412               60     100.00           6000.00
# 53          10424               50     100.00           5000.00
# 744         10322               50     100.00           5000.00
# 598         10407               76     100.00           7600.00
#
#       ORDERLINENUMBER        SALES  ORDERDATE      STATUS  QTR_ID  MONTH_ID  \
# 2249                6    556.86015 2005-05-31  In Process       2         5
# ...

# %%
#Rename one column
df2.rename(columns={"YEAR_ID":"YEAR","MONTH_ID":"MONTH"},inplace=True)
df2
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  CALCULATED_PRICE  \
# 2249        10425               11      43.83            482.13
# 1287        10407                6      90.19            541.14
# 2044        10408               15      36.93            553.95
# 1551        10280               20      28.88            577.60
# 1818        10419               15      42.67            640.05
# ...           ...              ...        ...               ...
# 104         10403               66     100.00           6600.00
# 1062        10412               60     100.00           6000.00
# 53          10424               50     100.00           5000.00
# 744         10322               50     100.00           5000.00
# 598         10407               76     100.00           7600.00
#
#       ORDERLINENUMBER        SALES  ORDERDATE      STATUS  QTR_ID  MONTH  ...  \
# 2249                6    556.86015 2005-05-31  In Process       2      5  ...
# ...

# %%
#UNIQUE()-->get unique Values
df2["SALES"].unique()
#nunique()---->Count unique Values
df2.nunique()
# Out:
# ORDERNUMBER          307
# QUANTITYORDERED       58
# PRICEEACH           1016
# CALCULATED_PRICE    1543
# ORDERLINENUMBER       18
# SALES               2763
# ORDERDATE            252
# STATUS                 6
# QTR_ID                 4
# MONTH                 12
# YEAR                   3
# PRODUCTLINE            7
# MSRP                  80
# PRODUCTCODE          109
# CUSTOMERNAME          92
# PHONE                 91
# ADDRESSLINE1          92
# CITY                  73
# STATE                 16
# POSTALCODE            73
# COUNTRY               19
# CONTACTLASTNAME       77
# CONTACTFIRSTNAME      72
# DEALSIZE               3
# dtype: int64

# %%
#pivot tables---->Used for summarizing data
pd.pivot_table(df2,values="SALES",index="CITY",aggfunc="sum")
# Out:
#                      SALES
# CITY
# Aaarhus       116187.86025
# Allentown     141069.55170
# Barcelona      90565.69830
# Bergamo       159338.85660
# Bergen        128944.52340
# ...                    ...
# Toulouse       81414.14820
# Tsawassen      86203.25175
# Vancouver      86900.95260
# Versailles     74883.63960
# White Plains   98817.16845
#
# [73 rows x 1 columns]

# %%
df2.dtypes
# Out:
# ORDERNUMBER                  int64
# QUANTITYORDERED              int64
# PRICEEACH                  float64
# CALCULATED_PRICE           float64
# ORDERLINENUMBER              int64
# SALES                      float64
# ORDERDATE           datetime64[ns]
# STATUS                      object
# QTR_ID                       int64
# MONTH                        int64
# YEAR                         int64
# PRODUCTLINE                 object
# MSRP                         int64
# PRODUCTCODE                 object
# CUSTOMERNAME                object
# PHONE                       object
# ADDRESSLINE1                object
# CITY                        object
# STATE                       object
# POSTALCODE                  object
# COUNTRY                     object
# CONTACTLASTNAME             object
# CONTACTFIRSTNAME            object
# DEALSIZE                    object
# dtype: object

# %%
df2
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  CALCULATED_PRICE  \
# 2249        10425               11      43.83            482.13
# 1287        10407                6      90.19            541.14
# 2044        10408               15      36.93            553.95
# 1551        10280               20      28.88            577.60
# 1818        10419               15      42.67            640.05
# ...           ...              ...        ...               ...
# 104         10403               66     100.00           6600.00
# 1062        10412               60     100.00           6000.00
# 53          10424               50     100.00           5000.00
# 744         10322               50     100.00           5000.00
# 598         10407               76     100.00           7600.00
#
#       ORDERLINENUMBER        SALES  ORDERDATE      STATUS  QTR_ID  MONTH  ...  \
# 2249                6    556.86015 2005-05-31  In Process       2      5  ...
# ...

# %%
#Basic Visualization in pandas using pandas plot
# df2["SALES"].plot()
df2["CALCULATED_PRICE"].hist()
# Out:
# <Axes: >

# %%
df2.plot(kind='scatter',x="MONTH",y="SALES")
# Out:
# <Axes: xlabel='MONTH', ylabel='SALES'>

# %%
df2.to_csv("new_cleaned_sales_data.csv",index=False)
